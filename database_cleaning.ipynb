# %%
import pandas as pd

# %%
df = pd.read_csv('https://github.com/marsbenham/database/blob/main/imdb_top_1000.csv?raw=true')

# %%
df.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
import json

# %%
genre = [val.strip() for sublist in df['Genre'].str.split(",").tolist() for val in sublist]

# %%
import json
df['Genre'].to_json(orient='records', indent=4)

# %%
df['Stars']=df['Star1']+ ', '+ df['Star2'] + ', ' + df['Star3'] + ', ' + df['Star4']

#casts = (json.dumps(df['Stars'].reset_index().to_json(orient='records')))
#print(casts)
cast = []
for i in range(len(df)):
    data= (json.loads(df['Stars'].reset_index().to_json(orient='values')))
    cast.append(data[i])
    
df['Cast'] = cast
df.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
#data= (json.dump(df['Genre'].reset_index().to_json(orient='records')))


#res = pd.json_normalize(data)

print(data)
#print(res['Genre'])

# %%
#my_data = {'genre:' []}

#genres = []
#for i in range(len(df)):

   # data= (json.loads(df['Genre'].reset_index().to_json(orient='records')))
   # genres.append(data[i])
#res

# %%
#df['Genres']=genres

#new_df= df.drop(['Genre', 'Star1','Star2','Star3','Star4','Stars'],axis=1)

# %%
df.head()

# %%
#j= (df.groupby(['Genre'])
 #      .apply(lambda x: x[['Genre']].to_dict('records'))
  #     .reset_index()
   #    .rename(columns={0:'Genres'})
    #   .to_json(orient='index'))

#df['Genres'] = j

#df.drop(['Genre'], axis=1)

# %%
df.to_csv(r'/Users/mariahbenham/Desktop/database/finalproject/file.csv')
